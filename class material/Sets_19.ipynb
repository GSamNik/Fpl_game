# %% [markdown]
# # Sets
# { }
#
# items is unique
#
# unordered
#
# unindexed
#
# mutable

# %% [markdown]
# # search task
#  هي ال set مبنيه على ايه

# %%
l=[1,2,3,1,3,1,4,5,5,6,4,5]
unique_l=[]
for i in l:
  if i not in unique_l:
    unique_l.append(i)
print(unique_l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,1,3,1,4,5,5,6,4,5]
s=set(l) # unique
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
unique_l=list(s)
print(unique_l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l={1,2,3,1,3,1,4,5,5,6,4,5}
print(l)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # create empty set

# %%
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
s=set()
print(type(s))
# Out:
# <class 'set'>

# %%
n = {100,3,4,33,6,6,7} # iteratble | not sequence
print(n)
print(33 in n) # T | F
# Out:
# [100, 3, 4, 33, 6, 6, 7]
# True

# %%
n = {33,3,4,6,6,7}
for i in n:
  print(i)
# Out:
# 33
# 3
# 4
# 6
# 7

# %% [markdown]
# # Unordered

# %%
s={3,'rawan',4,'Amin','Mahmoud'}
print(s)
# Out:
# {3, 4, 'Amin', 'rawan', 'Mahmoud'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # not indexed

# %%
s={1,3,3,2,1}
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1420/1787871751.py in <cell line: 0>()
#       1 s={1,3,3,2,1}
# ----> 2 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s={3,'rawan',4,'Amin','Mahmoud'}
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-356218705.py in <cell line: 0>()
#       1 s={3,'rawan',4,'Amin','Mahmoud'}
# ----> 2 print(s[0])
#
# TypeError: 'set' object is not subscriptable

# %%
s={3,'rawan',4,'Amin','Mahmoud'}
print(s[1:3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1420/1889169675.py in <cell line: 0>()
#       1 s={3,'rawan',4,'Amin','Mahmoud'}
# ----> 2 print(s[1:3])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # Sets are mutable data type

# %% [markdown]
# # add

# %%
s = {1, 2, 3}
help(s.add)
# Out:
# Help on built-in function add:
#
# add(...) method of builtins.set instance
#     Add an element to a set.
#
#     This has no effect if the element is already present.

# %%
s = {1, 2, 3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {1, 2, 3}
s.add((1,2,3))
print(s)
# Out:
# {1, 2, 3, (1, 2, 3)}

# %%
s = {1, 2, 3}
s.add('rawan')
print(s)
# Out:
# {1, 2, 3, 'rawan'}

# %%
s = {1, 2, 3}
s.add([1,2,3])
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1420/914854401.py in <cell line: 0>()
#       1 s = {1, 2, 3}
# ----> 2 s.add([1,2,3])
#       3 print(s)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # Search Task: One-Line for Loop and List Comprehension

# %% [markdown]
# # remove

# %%
s.remove(2)
s
# Out:
# {1, 3}

# %% [markdown]
# # update: must take iter

# %%
s = {1, 2, 3}

help(s.update)
# Out:
# Help on built-in function update:
#
# update(...) method of builtins.set instance
#     Update a set with the union of itself and others.

# %%
s = {1, 2, 3}
# Add multiple elements from another iterable (list, set, tuple...)
s.update([3, 4, 5])
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {1, 2, 3}

s.update({3, 4, 5}) # iteratble elements

print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {1, 2, 3}

s.update(4) # iteratble elements

print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5796/1803278838.py in <cell line: 0>()
#       1 s = {1, 2, 3}
#       2
# ----> 3 s.update(4) # iteratble elements
#       4
#       5 print(s)
#
# TypeError: 'int' object is not iterable

# %%
s+={1,2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5796/1559076384.py in <cell line: 0>()
# ----> 1 s+={1,2}
#
# TypeError: unsupported operand type(s) for +=: 'set' and 'set'

# %%
s = {1, 2, 3}
a={2,3,4}
print(a+s) # merge must use update conceate no bec it not sequence dtype
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1420/3214593530.py in <cell line: 0>()
#       1 s = {1, 2, 3}
#       2 a={2,3,4}
# ----> 3 print(a+s) # merge must use update conceate no bec it not sequence dtype
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s = {1, 2, 3}
s.update(5) # iteratble elements
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5796/3895858960.py in <cell line: 0>()
#       1 s = {1, 2, 3}
# ----> 2 s.update(5) # iteratble elements
#       3 print(s)
#
# TypeError: 'int' object is not iterable

# %%
s = {1, 2, 3}
s.update([5]) # iteratble elements
print(s)
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# #copy

# %%
s = {1, 2, 3}
z=s.copy()
z.add(4)
print(s)
print(z)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}

# %%
s = {1, 2, 3}
z=s
z.add(4)
print(s)
print(z)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}

# %% [markdown]
# # pop

# %%
a=z.pop() # set mutable inplace | return remove
print(a)
z
# Out:
# 1
# {2, 3, 4}

# %%
s = {80,2,65,1,100}
print(s)
poped= s.pop()
print(poped)
print(s)

s.add(90)
print(s)

s.add(80)
print(s)

x=s.pop()
print(x)
print(s)
# Out:
# {80, 65, 2, 1, 100}
# 80
# {65, 2, 1, 100}
# {65, 2, 1, 100, 90}
# {80, 65, 2, 1, 100, 90}
# 65
# {80, 2, 1, 100, 90}

# %% [markdown]
# # Clear

# %%
s={1,2,3,3}
s.clear()
s
# Out:
# set()

# %% [markdown]
# # frozen set

# %%
s = frozenset([2,4,'a','c'])  # immutable
print(s)
# Out:
# frozenset({2, 4, 'a', 'c'})

# %%
s = frozenset({2,4,'a','c'})  # immutable

print(s)
# Out:
# frozenset({2, 4, 'a', 'c'})

# %%
s.add(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1420/2986371146.py in <cell line: 0>()
# ----> 1 s.add(5)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# # Set operations
# # while True
#
#
# # union

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a={1,2,3}
b={3,4,5}
a | b
# Out:
# {1, 2, 3, 4, 5}

# %%
a
# Out:
# {1, 2, 3}

# %%
a={1,2,3}
b={3,4,'a',5}
a | b
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
a={1,2,3}
b={3,4,'a',5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
A = {2, 4, 5, 6}
B = {4, 6, 7, 8}
C = {7, 8, 9, 10}

print("A U B:", A | B)
print("A U B U C:", A | B | C)
# Out:
# A U B: {2, 4, 5, 6, 7, 8}
# A U B U C: {2, 4, 5, 6, 7, 8, 9, 10}

# %% [markdown]
# # intersection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a={1,2,3}
b={3,4,5}
a & b
# Out:
# {3}

# %%
a={1,2,3}
b={2,3,4,5} # {2,3} & c ---> {3}
c={3,5,6,7}
a & b & c
# Out:
# {3}

# %%
x=a.intersection(b)
print(x)
x.intersection(c)
# Out:
# {2, 3}
# {3}

# %% [markdown]
# # differance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a={4, 5, 6, 7, 8, 9}  # الموجود في a و مش موجود في b   | without intersection point
b={1, 2, 3, 4, 5, 6, 9}

a - b
# Out:
# {7, 8}

# %%
a={4, 5, 6, 7, 8, 9}
b={1, 2, 3, 4, 5, 6, 9}

b - a
# Out:
# {1, 2, 3}

# %%
print(a.difference(b))
# Out:
# {8, 7}

# %%
print(b.difference(a))
# Out:
# {1, 2, 3}

# %% [markdown]
# # symmetric

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# union - intersection
a={4, 5, 6, 7, 8, 9}
b={1, 2, 3, 4, 5, 6, 9}

a ^ b # union 1,2,3,4,5,6,7,8,9 - intersection 4,5,6,9 --> 1,2,3,7,8
# Out:
# {1, 2, 3, 7, 8}

# %%
a={4, 5, 6, 7, 8, 9}
b={1, 2, 3, 4, 5, 6, 9}

print((a|b)-(a&b))
a ^ b
# Out:
# {1, 2, 3, 7, 8}
# {1, 2, 3, 7, 8}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 3, 7, 8}

# %%
b.symmetric_difference(a)
# Out:
# {1, 2, 3, 7, 8}

# %%
a
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
b
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %% [markdown]
# # another operation

# %%
x = {1,2,4,3}
y = {1,4,3,7}
print(x == y)
# Out:
# False

# %%
x = {1,2,4,3}
y = {1,4,3,2}
print(x == y)
# Out:
# True

# %%
x = {1,2,3}
y = {1,3,4,3}
print(x == y)
# Out:
# False

# %%
x = {1,2,3}
y = {1,3,3,2,4,6}

print(x<=y) # are x subset from y جزئيه
# Out:
# True

# %%
x.issubset(y) # is --> T|F
# Out:
# True

# %%
x = {1,2,3}
y = {1,3,3,2,4}

print(x>=y) # are x is a superset of y.
# Out:
# False

# %%
x = {1,2,3}
y = {1,3,3,2,4}

print(y>=x)
# Out:
# True

# %%
y.issuperset(x)
# Out:
# True

# %% [markdown]
# # Sets functions

# %%
a = {1, 2, 3, 7, 8, 9, 9}

# %%
print(len(a))

print(max(a))

print(min(a))

print(sum(a))
# Out:
# 6
# 9
# 4
# 39

# %%
s = {12, 10, 14}
print(sum(s))
# Out:
# 36
