# %% [markdown]
# # Search Task Answer How much python allocate for each datatype

# %%
print('Ali')
                print('ahmed')
# Out:
#   File "/tmp/ipykernel_909/2731192964.py", line 2
#     print('ahmed')
#     ^
# IndentationError: unexpected indent

# %%
print('rawan')
  print('mahmoud')
# Out:
#   File "/tmp/ipykernel_912/4176623732.py", line 2
#     print('mahmoud')
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # If Condition

# %%
if True:
  print('rawan')
# Out:
# rawan

# %%
a=1

if a==2: # False
  print('Yes')

# %% [markdown]
# ## if Condition
#
# syntax
#
# if Condition :
#
#
#
#       block
#
#
# **if execute when condition is True**

# %%
if 2==2: # true
   print('Yes')

# %%
if True:
  print('done')
# Out:
# done

# %%
if 2==2:
                  print('Yes')
                  print('Outside')
# Out:
# Yes
# Outside

# %%
if 1==2:
  print('yes')

print('outside')
# Out:
# outside

# %%
if 1: # like if True
  print('hello')
# Out:
# hello

# %%
if 0: # like if True
  print('hello')

# %% [markdown]
# # Else

# %%
else:
  print("Hello")
# Out:
#   File "/tmp/ipykernel_912/1136236041.py", line 1
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
weather = 'rainy'

if weather == 'Rainy':
    print('Wear a jacket')
    print('it\'s so cold')
else:
  print('Don\'t wear a jacket')
  print('Done')
  a=1
  b=1
  print(a+b)
# Out:
# Don't wear a jacket
# Done
# 2

# %% [markdown]
# # Login Example

# %%
z='RAWAn'
z.upper()
# Out:
# 'RAWAN'

# %%
user_name=input('plz eter user name ').lower()# RAWAN --> rawan
password=input('plz enter pass ')

if user_name == 'rawan' and password == '1234':
  print('welcome admin')

elif user_name=='mohamed' and password=='1111':
  print('welcome agmed ceo fi el donyaaaaaaaa')

elif user_name=='mahmoud' and password=='1351':
  print('welcome mahmoud ceo fi el donyaaaaaaaa')

else:
  print('Invalid user or pass')
# Out:
# plz eter user name rawan
# plz enter pass 111111
# Invalid user or pass

# %%
user_name=input('plz eter user name ').lower()# RAWAN --> rawan
password=input('plz enter pass ')


if user_name=='rawan':
  if password=='1234':
    print('Welcome')
  else:
    print('invalid password')

else:
  print('invalid user name')
# Out:
# plz eter user name rawan
# plz enter pass 1111
# invalid password

# %%
if 1==2:
  print('fjdvjns')

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if (user_name=='Rawan' and password==1234): # diff data type to comapre
  print('Welcome')
else:
  print('Invalid user name or password')
# Out:
# Plz enter your namerawan
# Plz enter your pass1234
# Invalid user name or password

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if (user_name=='Rawan' and password=='1234'): # diff data type to comapre
  print('Welcome')
else:
  print('Invalid user name or password')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1909/1136124570.py in <cell line: 0>()
# ----> 1 user_name=input("Plz enter your name") # Rawan
#       2 password=input("Plz enter your pass") # 1234
#       3
#       4 if (user_name=='Rawan' and password=='1234'): # diff data type to comapre
#       5   print('Welcome')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if ( (user_name=='Rawan' or user_name=='rawan') and password=='1234'): # diff data type to comapre
  print('Welcome')
else:
  print('Invalid user name or password')

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if (  (user_name=='Rawan' or user_name=='rawan') and password=='1234'): # diff data type to comapre
  print('Welcome')
  print('Your user name is: ', user_name)

  a=1
  b=2
  print(a+b)
else:
  print('Invalid user name or password')

  x=10
  y=20
  print(x+y)

# %% [markdown]
# # Many accounts

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if (user_name=='rawan' or user_name=='010') and password=='1234':
  print('Welcome user')

elif (user_name=='instant' or user_name=='011') and password=='1111':
  print('Welcome admin')

elif (user_name=='mohamed' or user_name=='015') and password=='2222':
  print('Welcome agmed CEO ')

else:
  print('This account not found')


print('Thank you')

# %% [markdown]
# # WAP code that check if age greater that 18

# %%
age=int(input('Plz Enter Your Age'))

if age >= 18:
  print('Adult')
else:
  print('Child')
# Out:
# Plz Enter Your Age12
# Child

# %%
age=int(input('Plz Enter Your Age'))

if age >= 18: # True
  print('Adult')
elif age >=12: #
  print('Teenager')
else:
  print('Child')
# Out:
# Plz Enter Your Age20
# Adult

# %% [markdown]
# # Grade System

# %%
score=float(input('enter score '))
if score >=90 and score <=100:
  print('A')
elif score >=80 and score < 90:
  print('B+')
elif score >=70 and score < 80:
  print('B')
elif score >=60 and score < 70:
  print('c')
elif score >=50 and score < 60:
  print('D')
elif score < 50 and score >=0 :
  print('F')
else:
  print('Invalid')

# %%
score=int(input('Plz enter your score'))

if score >= 90 and score <= 100:
  print('A')
elif score >=80 and score <= 89:
  print('B+')
elif score >=70 and score <= 79:
  print('B')
elif score >=60 and score <= 69:
  print('C')
elif score >=50 and score <= 59:
  print('D')
elif score < 50 and score >= 0:
  print('F')
else:
  print('Invalid Score')

# %%
score=int(input('Plz enter your score'))
if  100 >= score >= 90:
  print('A')
elif 89 >= score >=80:
  print('B+')
elif 79 >= score >=70:
  print('B')
elif 69 >=score >=60:
  print('C')
elif 59 >=score >=50:
  print('D')
elif 0 <= score < 50 :
  print('F')
else:
  print('Invalid Score')

# %%
score=int(input('Plz enter your score'))

if score < 0 or score >100:
  print('invalid')

elif score >=90:
  print('A')

elif score >=80:
  print('B+')
elif score >=70:
  print('B')
elif score >=60:
  print('C')
elif score >=50:
  print('D')
elif score < 50:
  print('f')
# Out:
# Plz enter your score66
# C

# %%
grade=int(input('enter your grade '))
bouns= 0
if 100 >= grade >= 90:
  bouns+=10 # bouns=bouns+10
elif 89 >= grade >= 80:
  bouns+=5
else:
  print('no addition ')
print(bouns)

# %% [markdown]
# # WAP to enter a number from user and check if it is even or odd.

# %%
num=int(input('plz num'))

if num % 2 ==0:
  print('even')
else:
  print('odd')
# Out:
# plz num2
# even

# %%
if 0 :
  print('no')

# %%
num=int(input('Enter Number'))
if num %2 ==0:
  print('Even')
else:
  print('Odd')

# %% [markdown]
# # WAP to enter number from user and return its absloute

# %%
num=int(input())

if num < 0:
  print(-num)
else:
  print(num)
# Out:
# -9
# 9

# %%
num=int(input())
print(abs(num))
# Out:
# -10
# 10

# %%
-4 * -1
# Out:
# 4

# %%
num=int(input('enter number'))

if num >=0:
  print(num)
else:
  print(-1*num)

# %%
num=int(input('enter number'))

if num >=0:
  print(num)
else:
  print(-num)
# Out:
# enter number-9
# 9

# %%
num=int(input('enter number'))
print(abs(num))
# Out:
# enter number9
# 9

# %% [markdown]
# # Nested If

# %%
user_name=input("Plz enter your name").lower() # Rawan
password=input("Plz enter your pass") # 1234

if user_name=='rawan': # diff data type to comapre

   if password=='1234':
      print('welcome')
   else:
      print('Invalid Password')
else:
  print('Invalid user name')
# Out:
# Plz enter your namerawan
# Plz enter your pass1231
# Invalid Password

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if  user_name=='rawan': # diff data type to comapre
    if password == '1234':
      print('Welcome user')
    else:
      print('Invalid Password')
else:
  print('Invalid user name')
# Out:
# Plz enter your namerawan
# Plz enter your pass1234
# Welcome user

# %%
user_name=input("Plz enter your name") # Rawan
password=input("Plz enter your pass") # 1234

if  user_name=='rawan': # diff data type to comapre
    if password == '1234':
      print('Welcome user')
    else:
      print('Invalid Password')

elif user_name=='Mohamed':
  if password=='1111':
    print("Welcome Agmed CEO")
  else :
    print('Invalid Password')

else:
  print('Invalid user name')
# Out:
# Plz enter your nameMohamed
# Plz enter your pass11
# Invalid Password

# %% [markdown]
# # Tenary statement: A ternary if is a one-line if-else used to assign a value based on a condition.
#
#
# ```
# <value_if_true> if <condition> else <value_if_false>
# ```

# %%
status=True

if status==True:
  print('True')
else:
  print('False')
# Out:
# True

# %%
print('True' if status == True else 'False')
# Out:
# True

# %%
Status=True
if Status==True:
  print('Welcome')
else:
  print('Invalid')
# Out:
# Welcome

# %%
age =14

# %%
Status=True

print('Welcome' if Status == True else 'Invalid')
# Out:
# Welcome

# %%
age=20
if age>=18:
  status='adult'
else:
  status='child'

print(status)
# Out:
# adult

# %%
age=18

status = 'adult' if age> 18 else 'child' if age < 18 else 18
status
# Out:
# 18

# %%
age=14

status='adult' if age >=18 else 'child'
print(status)
# Out:
# child

# %%
age = 22

status = "adult" if age > 18 else "minor" if age < 18 else 18
print(status)
# Out:
# adult
