# %% [markdown]
# # Boolean

# %%
a= 100==1000
print(a)
print(type(a))
# Out:
# False
# <class 'bool'>

# %%
print(100==100)
# Out:
# True

# %%
print(100==20)
# Out:
# False

# %% [markdown]
# # True cases

# %%
# True---> 1 2 3 4
# False ---> 0

# %%
bool(1)
# Out:
# True

# %%
bool(5)
# Out:
# True

# %%
bool(-8)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(100>20)
# Out:
# True

# %%
bool('rawan')
# Out:
# True

# %% [markdown]
# # False

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool('')
# Out:
# True

# %%
bool(False)
# Out:
# False

# %% [markdown]
# #  Boolean (Logic) Operators
#
# ## AND
#
# | A     | B     | A and B |
# | ----- | ----- | ------- |
# | True  | True  | True    |
# | True  | False | False   |
# | False | True  | False   |
# | False | False | False   |
#
#
#
# ## OR
#
# | A     | B     | A or B |
# | ----- | ----- | ------ |
# | True  | True  | True   |
# | True  | False | True   |
# | False | True  | True   |
# | False | False | False  |
#
#
# ## NOT
#
# | A     | not A |
# | ----- | ----- |
# | True  | False |
# | False | True  |

# %%
not(False) # نفي ال نفي اثبات
# Out:
# True

# %%
not(True) #نفي الاثبات نفي
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and True
# Out:
# True

# %%
(True and True) and (False and True)
#  T                     F  ==> F

#      T         and     False ---> False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
(True and True) or (False and True)
#      T        or      False ---> True
# Out:
# True

# %%
True and False and not False or True or not False
#     F         F             T       T  --> T
# Out:
# True

# %%
name = 'rawan'
country='egypt'
city='cairo'

print(name =='rawan' or country=='KSA')
# Out:
# True

# %%
print(name =='rawan' and country=='KSA')
# Out:
# False

# %%
print(name =='rawan' or country=='KSA' and city=='cairo')
#        T                       F
# Out:
# True

# %%
not(name =='rawan')  and  not(country=='KSA' and city=='cairo')
#      F
# Out:
# False

# %% [markdown]
# # Arithmetics Operators
#
#
#
# ```
# +, -, *, /, %, **, //
#
# ```

# %% [markdown]
# # operator precedence
#
# ## 1. **brackets**
# | Operator | Description           | Example           |
# |----------|------------------------|-------------------|
# | `()`     | Grouping               | `(2 + 3) * 4`      |
#
# ---
#
# ## 2. **Exponentiation**
# | Operator | Description           | Example           |
# |----------|------------------------|-------------------|
# | `**`     | Power (Exponent)       | `2 ** 3` → `8`     |
#
# ---
#
# ## 3. **Multiplicative Operators**
# | Operator | Description           | Example           |
# |----------|------------------------|-------------------|
# | `*`      | Multiplication         | `3 * 4` → `12`     |
# | `/`      | Division               | `10 / 2` → `5.0`   |
# | `//`     | Floor Division         | `10 // 3` → `3`    |
# | `%`      | Modulo (Remainder)     | `10 % 3` → `1`     |
#
# ---
#
# ## 4. **Additive Operators**
# | Operator | Description           | Example           |
# |----------|------------------------|-------------------|
# | `+`      | Addition               | `3 + 2` → `5`      |
# | `-`      | Subtraction            | `5 - 1` → `4`      |
#
# ---

# %%
1+1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
2**3 # power
# Out:
# 8

# %%
a=4/2
print(a)
print(type(a))
# Out:
# 2.0
# <class 'float'>

# %%
a=5//2 # 2
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
a=10/5
print(a)
print(type(a))
# Out:
# 2.0
# <class 'float'>

# %%
a=10//5
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
a=10/3
print(a)
print(type(a))
# Out:
# 3.3333333333333335
# <class 'float'>

# %%
a=10//3 # floor division
print(a)
print(type(a))
# Out:
# 3
# <class 'int'>

# %%
a=5.5//2#
print(a)
print(type(a))
# Out:
# 2.0
# <class 'float'>

# %%
6%2# 6/2 = 3 no r= 0
# Out:
# 0

# %%
b=6/2 # 6/2 ==> 3 no reminder so it == 0
print(b)
print('-'*20)
a=6%2
print(a)
# Out:
# 3.0
# --------------------
# 0

# %%
5%2# 5/2--> 2.5 | 0.5*2=1
# Out:
# 1

# %%
b=5/2
print(b)

print('-'*20)

a=5%2 # 5/2  = 2.5 | 0.5 *2 = 1
print(a)
# Out:
# 2.5
# --------------------
# 1

# %%
0.4*5
# Out:
# 2.0

# %%
a=22%5
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
22/5
# Out:
# 4.4

# %%
0.4*5
# Out:
# 2.0

# %%
a=4.5%2 # 2.25 --> 0.25 *2=0.5
print(a)
print(type(a))
# Out:
# 0.5
# <class 'float'>

# %%
0.25*2
# Out:
# 0.5

# %%
n=float(input('enter'))
a=n%5
print(a)
print(type(a))
# Out:
# enter10.0
# 0.0
# <class 'float'>

# %%
n=6
n%2
# Out:
# 0

# %% [markdown]
# # Assignment Operators
#
# Assignment operators are used to assign values to variables.
#
# | Operator | Description              | Example      | Same As         |
# |----------|--------------------------|--------------|------------------|
# | `+=`     | Add and assign           | `x += 3`     | `x = x + 3`      |
# | `-=`     | Subtract and assign      | `x -= 2`     | `x = x - 2`      |
# | `*=`     | Multiply and assign      | `x *= 4`     | `x = x * 4`      |
# | `/=`     | Divide and assign        | `x /= 2`     | `x = x / 2`      |
# | `//=`    | Floor divide and assign  | `x //= 2`    | `x = x // 2`     |
# | `%=`     | Modulo and assign        | `x %= 3`     | `x = x % 3`      |
# | `**=`    | Power and assign         | `x **= 2`    | `x = x ** 2`     |

# %%
x=5

# %%
x+=1 # x=x+1 x++
print(x) # x=1+1
# Out:
# 6

# %%
x-=1 # x=x-1
print(x)
# Out:
# 5

# %%
x=6

x+=3 # x=x+3

x
# Out:
# 9

# %%
a=10
# a = a+5  # 10 + 5
a+=5
a
# Out:
# 15

# %%
a=10

b=a # assgin value a to b

print(b)
print(a)
# Out:
# 10
# 10

# %%
a=10
a += 5 # a = a + 5 = 10+5=15
a *= 2   # a = a *2 = 15 *2 = 30
print(a)
# Out:
# 30

# %%
a=10
a%=2  # a=a%2
a
# Out:
# 0

# %%
a=2
a**=3 # 2**3
a
# Out:
# 8

# %%
++
--
a=10
a++ #error
# Out:
#   File "/tmp/ipykernel_1105/942186204.py", line 1
#     ++
#       ^
# SyntaxError: invalid syntax

# %%
a=4
a+=1 # ++
# b=a+10
a
# Out:
# 5

# %% [markdown]
# # Relational Operators (also called comparison operators)
#
# Relational operators are used to **compare values**. They always return a **Boolean result** — either `True` or `False`.
#
# ---
#
#
# | Operator | Description           | Example         | Result        |
# |----------|------------------------|-----------------|---------------|
# | `==`     | Equal to               | `5 == 5`        | `True`        |
# | `!=`     | Not equal to           | `5 != 3`        | `True`        |
# | `>`      | Greater than           | `7 > 4`         | `True`        |
# | `<`      | Less than              | `3 < 6`         | `True`        |
# | `>=`     | Greater than or equal  | `5 >= 5`        | `True`        |
# | `<=`     | Less than or equal     | `4 <= 5`        | `True`        |
#
# ---

# %%
print(10 > 5 and 5 < 3)
#     True and  False --> False
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
print(11  % 2 == 0)
#
# Out:
# False

# %%
print(9 % 2 == 0)
# Out:
# False

# %%
print(8 % 2 == 0)
# Out:
# True

# %%
print(10 == 10.0001)
# Out:
# False

# %%
print(6 % 2 == 0 and 7 % 2 !=0 )
#        True     and   True
# Out:
# True

# %%
n=int(input('enter'))
print(n%2==0)
# Out:
# enter11
# False
