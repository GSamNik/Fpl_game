# %% [markdown]
# # Create Function Print Even Numbers from a Given List
#
# Write a Python program to print the even numbers from a given list.
#
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]

# %% [markdown]
# # Create Function Count Vowels and Consonants
#
# Write a Python function that accepts a string and counts the number of vowels and consonants.

# %% [markdown]
# # Create Function Count Uppercase and Lowercase Letters in a String
#
# Write a Python function that accepts a string and counts the number of upper and lower case letters.
#
# Sample String : 'The quick Brow Fox'
#
# Expected Output :
# - No. of Upper case characters : 3
# - No. of Lower case Characters : 12

# %% [markdown]
# # Shopping Cart System
#
# Problem Statement
#
# Write a Python program to simulate a Shopping Cart System using functions.
#
# The program should maintain a product catalog and allow users to perform different shopping operations through a menu.
# ```
# Requirements
# Display all available products with their:
#   Product ID
#   Name
#   Price
#   Available Quantity
#   Add a product to the shopping cart.
#   The product ID must exist.
#
# - The requested quantity cannot exceed the available stock.
# - Remove a product from the shopping cart.
# Update the quantity of an existing product in the cart.
# - If the quantity becomes zero, remove the product from the cart.
# - Search for a product by its name.
# - Calculate the shopping bill.
#
# Display:
#    Subtotal
#    Discount (10% if subtotal exceeds 1000)
#    Tax (14%)
#    Final Total
#
# Print a receipt showing:
#   Purchased products
#   Quantity
#   Unit price
#   Total price for each product
#   Final bill
#   After checkout:
#   Update the inventory.
#   Empty the shopping cart.

# %% [markdown]
# # Sort Tuples by Last Element
#
# Write a Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples.
#
# - Sample List : [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]
# - Expected Result : [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %% [markdown]
# # Find Words Longer Than n
#
# Write a Python program to find the list of words that are longer than n from a given list of words.

# %% [markdown]
# # Find the Tuple with the Largest Sum
#
# Write a Python program to find the tuple with the largest sum of its elements.
#
# Sample Input
#
# [(2, 3), (5, 6), (1, 9), (4, 4)]
#
# Expected Output
#
# (5, 6)

# %% [markdown]
# # Count Occurrences of the First Element
#
# Write a Python program to count how many times each first element appears in a list of tuples.
#
# Sample Input
#
# [(1, 4), (2, 5), (1, 7), (3, 8), (2, 9)]
#
# Expected Output
#
# {1: 2, 2: 2, 3: 1}

# %% [markdown]
# # Remove Duplicate Tuples
#
# Write a Python program to remove duplicate tuples from a list while preserving their original order.
#
# Sample Input
#
# [(1, 2), (3, 4), (1, 2), (5, 6), (3, 4)]
#
# Expected Output
#
# [(1, 2), (3, 4), (5, 6)]

# %% [markdown]
# # Calculate the Average of the Second Elements
#
# Write a Python program to calculate the average of the second element from each tuple.
#
# Sample Input
#
# [(1, 10), (2, 20), (3, 30), (4, 40)]
#
# Expected Output
#
# 25.0
