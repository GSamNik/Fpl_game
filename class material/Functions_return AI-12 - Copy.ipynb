# %% [markdown]
# # Return Statement

# %%
def add(n1,n2):
  print(n1+n2) # display not value


add(1,2)
# Out:
# 3

# %%
def add(n1,n2):
  print(n1+n2) # display not value
print(add(1,2))
# Out:
# 3
# None

# %%
def add(n1,n2):
  print(n1+n2) # display not value
a=add(1,2)
a+1
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1548/2203115097.py in <cell line: 0>()
#       2   print(n1+n2) # display not value
#       3 a=add(1,2)
# ----> 4 a+1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def add(n1,n2):
  return n1+n2 # display not value

a=add(1,2)
a+1
# Out:
# 4

# %%
l=[111,232]
print(l.append(11))
l
# Out:
# None
# [111, 232, 11]

# %%
def add(n1,n2):
  print(n1+n2)
  # return None
print(add(1,2))
# Out:
# 3
# None

# %%
def add(n1,n2):
  print(n1+n2)
  # return None
a=add(1,2)#3
print(a)
# Out:
# 3
# None

# %%
def add(n1,n2):
  return n1+n2
add(1,2)
# Out:
# 3

# %%
def add (x,y):
  print(x+y)

a=add(1,2)
print(a)
# Out:
# 3
# None

# %%
l=[1,2,3,4]
l.reverse()

# %%
print(l.reverse()) # inplace not return
# Out:
# None

# %%
l
# Out:
# [4, 3, 2, 1]

# %%
help(l.reverse)
# Out:
# Help on built-in function reverse:
#
# reverse() method of builtins.list instance
#     Reverse *IN PLACE*.

# %%
l=[1,2,34]
a=max(l) # can store it bec it return a value
print(a)
# Out:
# 37

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %% [markdown]
# ## return: any function has return statement

# %%
def say_hi(paramter):
  print('Hi',paramter)
  return 'nice' # after return not printed --> return means it is end of the function
  return 'okay'



name=input('enter your name: ')
print(say_hi(name))
# Out:
# enter your name: 111
# Hi 111
# nice

# %%
def say_hi(paramter):
  print('Hi',paramter)
  return 'hello'
  return 'okay' # after return not printed --> return means it is end of function
name=input('enter your name: ').capitalize()
print(say_hi(name))
# Out:
# enter your name: 1
# Hi 1

# %% [markdown]
# 3# create a Function that multiply 2 number

# %%
def multiply(a,b):
  mul=a*b
  return mul
a=3
b=4
multiply(a,b)
print()

# %%
def multiply(a,b):
  mul=a*b
  return mul
a=3
b=4
a=multiply(a,b)
a+3
# Out:
# 15

# %%
def multiply(a,b):
  return f'{a} X {b} = {a*b}'
a=3
b=4
print(multiply(a,b))
# Out:
# 3 X 4 = 12

# %%
def multiply(a,b):
  print(a*b)
  print(a)
  print(b)
  return f'{a} X {b} = {a*b}'
  print(b)
a=3
b=4
print(multiply(a,b))
print()
# Out:
# 12
# 3
# 4
# 3 X 4 = 12

# %% [markdown]
# ## Defult parameter

# %%
print?

# %%
print('rawan','amin') # by defult end=\n
print('mahmoud')
# Out:
# rawan amin
# mahmoud

# %%
s
# Out:
# 'rawan'

# %%
s='rawan'
s.replace('r',) # new value should be found bec, it is not defult
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1183461314.py in <cell line: 0>()
#       1 s='rawan'
# ----> 2 s.replace('r',) # new value should be found bec, it is not defult
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
def power(n,p=2):
  return n**p

print(power(2))
print(power(3,10))
# Out:
# 4
# 59049

# %%
print(power())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2049/4092780527.py in <cell line: 0>()
# ----> 1 print(power())
#
# TypeError: power() missing 1 required positional argument: 'n'

# %%
def say(msg, times=3):
    print(msg * times)

# %%
def say(times=3,msg):
    print(msg * times)
# Out:
#   File "/tmp/ipykernel_2049/3763522497.py", line 1
#     def say(times=3,msg):
#                     ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
n=input('enter')
say(n)#
say(n,4)
# Out:
# enterrawan
# 3
# rawanrawanrawanrawan

# %%
n=input('enter')
def say(msg, times=3):
    print(msg * times)
say(2,n)
# Out:
# enterhi
# hihi

# %%
say(times=2,msg=n)
# Out:
# hihi

# %%
say(times=2,msg=3)
# Out:
# 6

# %%
say(times=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-169714250.py in <cell line: 0>()
# ----> 1 say(times=2)
#
# TypeError: say() missing 1 required positional argument: 'msg'

# %% [markdown]
# ## Define a function named 'test_range' that checks if a number 'n' is within the range 3 to 8 (inclusive)

# %%
def test_range(n):
  if n in range(3,9):
    return True
  return False

# %%
def test_range(n):
  if n in range(3,9):
    return True
  return False
test_range(5)
# Out:
# True

# %% [markdown]
# ## Define a function named chars_mix_up that takes two arguments, a and b.
#
# a = "abc"
#
# b = "xyz"
#
# output xyc abz

# %%
def chars_mix_up(a,b):
  new_str=b[:-1]+a[-1]+' '+a[:-1]+b[-1]
  return new_str
a=input('enter str')
b=input('enter str')
print(chars_mix_up(a,b))
# Out:
# enter strabc
# enter strxyz
# xyc abz

# %%
def chars_mix_up(a,b):
  return b[:2]+a[-1]+' '+a[:2]+b[-1]
print(chars_mix_up('abc','xyz'))
# Out:
# xyc abz

# %%
def chars_mix_up(a,b):
  return b[:2]+a[-1]+' '+a[:2]+b[-1]
p=chars_mix_up('abc','xyz')
p+' '+ 'rawan'
# Out:
# 'xyc abz rawan'
